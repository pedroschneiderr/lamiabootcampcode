# %%
import numpy as np
import sklearn
from tensorflow.keras.datasets import mnist
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import InputLayer, Dense,BatchNormalization, Conv2D, Flatten, MaxPooling2D
from tensorflow.keras import utils
from sklearn.model_selection import StratifiedKFold

# %%
(X, y), (X_test, y_test) = mnist.load_data()

# %%
X = X.reshape(X.shape[0], 28, 28, 1) # adição da dimensão de canais de cores
X = X.astype('float32') # conversão de inteiro para float para normalização
X /= 255 # normalização
y = utils.to_categorical(y, 10) # conversão das 10 classes para codificação One Hot

# %%
seed = 5
np.random.seed(seed) # assinala uma seed para reproducibilidade

# %%
kfold = StratifiedKFold(n_splits = 5, shuffle = True, random_state = seed)

# %% [markdown]
# A célula acima cria uma instância de StratifiedKFold com 5 folds, propriedade de shuffle (embaralhar os dados antes da separação das folds) e uma random state para reproducibilidade.

# %%
results = [] # onde serão armazenados os resultados da Cross Validation
for train_index, test_index in kfold.split(X, np.zeros(shape = (y.shape[0], 1))):
    classifier = Sequential()
    classifier.add(InputLayer(shape = (28, 28, 1)))
    classifier.add(Conv2D(filters = 32, kernel_size = (3, 3), activation = 'relu'))
    classifier.add(BatchNormalization())
    classifier.add(MaxPooling2D(pool_size = (2, 2)))
    classifier.add(Flatten())
    classifier.add(Dense(units = 128, activation = 'relu'))
    classifier.add(Dense(units = 10, activation = 'softmax'))
    
    classifier.compile(optimizer = 'adam', loss = 'categorical_crossentropy', metrics=['accuracy'])
    classifier.fit(X[train_index], y[train_index], batch_size = 128, epochs = 5)
    precision = classifier.evaluate(X[test_index], y[test_index])
    results.append(precision[1])
# Out:
# Epoch 1/5
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 20s 49ms/step - accuracy: 0.8922 - loss: 0.4034
# Epoch 2/5
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 19s 50ms/step - accuracy: 0.9884 - loss: 0.0407
# Epoch 3/5
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 18s 48ms/step - accuracy: 0.9929 - loss: 0.0211
# Epoch 4/5
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 18s 48ms/step - accuracy: 0.9956 - loss: 0.0134
# Epoch 5/5
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 18s 48ms/step - accuracy: 0.9970 - loss: 0.0085
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9836 - loss: 0.0683
# Epoch 1/5
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 19s 46ms/step - accuracy: 0.8887 - loss: 0.3761
# Epoch 2/5
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 18s 48ms/step - accuracy: 0.9870 - loss: 0.0434
# Epoch 3/5
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 18s 47ms/step - accuracy: 0.9926 - loss: 0.0220
# Epoch 4/5
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 18s 47ms/step - accuracy: 0.9968 - loss: 0.0117
# Epoch 5/5
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 17s 45ms/step - accuracy: 0.9972 - loss: 0.0086
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9848 - loss: 0.0642
# Epoch 1/5
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 19s 47ms/step - accuracy: 0.9075 - loss: 0.2982
# Epoch 2/5
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 18s 48ms/step - accuracy: 0.9872 - loss: 0.0402
# Epoch 3/5
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 17s 47ms/step - accuracy: 0.9935 - loss: 0.0199
# Epoch 4/5
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 18s 48ms/step - accuracy: 0.9966 - loss: 0.0104
# Epoch 5/5
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 18s 47ms/step - accuracy: 0.9977 - loss: 0.0074
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9857 - loss: 0.0651
# Epoch 1/5
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 18s 45ms/step - accuracy: 0.8939 - loss: 0.3487
# Epoch 2/5
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 17s 46ms/step - accuracy: 0.9881 - loss: 0.0381
# Epoch 3/5
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 17s 46ms/step - accuracy: 0.9940 - loss: 0.0187
# Epoch 4/5
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 17s 46ms/step - accuracy: 0.9970 - loss: 0.0105
# Epoch 5/5
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 17s 45ms/step - accuracy: 0.9985 - loss: 0.0055
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9809 - loss: 0.0836
# Epoch 1/5
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 19s 47ms/step - accuracy: 0.8986 - loss: 0.3414
# Epoch 2/5
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 17s 45ms/step - accuracy: 0.9845 - loss: 0.0485
# Epoch 3/5
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 17s 46ms/step - accuracy: 0.9927 - loss: 0.0227
# Epoch 4/5
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 17s 45ms/step - accuracy: 0.9955 - loss: 0.0142
# Epoch 5/5
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 17s 46ms/step - accuracy: 0.9968 - loss: 0.0105
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9797 - loss: 0.0744

# %%
results
# Out:
# [0.9831666946411133,
#  0.9806666374206543,
#  0.9858333468437195,
#  0.9815000295639038,
#  0.9804999828338623]

# %%
np.array(results).mean()
# Out:
# 0.9823333382606506

# %%
np.array(results).std()
# Out:
# 0.0019888705404558647
