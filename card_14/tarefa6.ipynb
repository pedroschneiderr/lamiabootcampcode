# %%
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import InputLayer, Dense, Dropout, BatchNormalization, Conv2D, Flatten, MaxPooling2D
from tensorflow.keras import backend as k
from tensorflow.keras import utils

# %%
(X_train, y_train), (X_test, y_test) = cifar10.load_data()
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 ━━━━━━━━━━━━━━━━━━━━ 6s 0us/step

# %% [markdown]
# Pré-processamento dos dados

# %%
X_train
# Out:
# array([[[[ 59,  62,  63],
#          [ 43,  46,  45],
#          [ 50,  48,  43],
#          ...,
#          [158, 132, 108],
#          [152, 125, 102],
#          [148, 124, 103]],
#
#         [[ 16,  20,  20],
#          [  0,   0,   0],
#          [ 18,   8,   0],
#          ...,
#          [123,  88,  55],
#          [119,  83,  50],
#          [122,  87,  57]],
#
#         [[ 25,  24,  21],
#          [ 16,   7,   0],
#          [ 49,  27,   8],
#          ...,
#          [118,  84,  50],
#          [120,  84,  50],
#          [109,  73,  42]],
#
#         ...,
#
#         [[208, 170,  96],
#          [201, 153,  34],
#          [198, 161,  26],
#          ...,
#          [160, 133,  70],
#          [ 56,  31,   7],
#          [ 53,  34,  20]],
#
#         [[180, 139,  96],
#          [173, 123,  42],
#          [186, 144,  30],
#          ...,
#          [184, 148,  94],
#          [ 97,  62,  34],
#          [ 83,  53,  34]],
#
#         [[177, 144, 116],
#          [168, 129,  94],
#          [179, 142,  87],
#          ...,
#          [216, 184, 140],
#          [151, 118,  84],
#          [123,  92,  72]]],
#
#
#        [[[154, 177, 187],
#          [126, 137, 136],
#          [105, 104,  95],
#          ...,
#          [ 91,  95,  71],
#          [ 87,  90,  71],
#          [ 79,  81,  70]],
#
#         [[140, 160, 169],
#          [145, 153, 154],
#          [125, 125, 118],
#          ...,
#          [ 96,  99,  78],
#          [ 77,  80,  62],
#          [ 71,  73,  61]],
#
#         [[140, 155, 164],
#          [139, 146, 149],
#          [115, 115, 112],
#          ...,
#          [ 79,  82,  64],
#          [ 68,  70,  55],
#          [ 67,  69,  55]],
#
#         ...,
#
#         [[175, 167, 166],
#          [156, 154, 160],
#          [154, 160, 170],
#          ...,
#          [ 42,  34,  36],
#          [ 61,  53,  57],
#          [ 93,  83,  91]],
#
#         [[165, 154, 128],
#          [156, 152, 130],
#          [159, 161, 142],
#          ...,
#          [103,  93,  96],
#          [123, 114, 120],
#          [131, 121, 131]],
#
#         [[163, 148, 120],
#          [158, 148, 122],
#          [163, 156, 133],
#          ...,
#          [143, 133, 139],
#          [143, 134, 142],
#          [143, 133, 144]]],
#
#
#        [[[255, 255, 255],
#          [253, 253, 253],
#          [253, 253, 253],
#          ...,
#          [253, 253, 253],
#          [253, 253, 253],
#          [253, 253, 253]],
#
#         [[255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255],
#          ...,
#          [255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255]],
#
#         [[255, 255, 255],
#          [254, 254, 254],
#          [254, 254, 254],
#          ...,
#          [254, 254, 254],
#          [254, 254, 254],
#          [254, 254, 254]],
#
#         ...,
#
#         [[113, 120, 112],
#          [111, 118, 111],
#          [105, 112, 106],
#          ...,
#          [ 72,  81,  80],
#          [ 72,  80,  79],
#          [ 72,  80,  79]],
#
#         [[111, 118, 110],
#          [104, 111, 104],
#          [ 99, 106,  98],
#          ...,
#          [ 68,  75,  73],
#          [ 70,  76,  75],
#          [ 78,  84,  82]],
#
#         [[106, 113, 105],
#          [ 99, 106,  98],
#          [ 95, 102,  94],
#          ...,
#          [ 78,  85,  83],
#          [ 79,  85,  83],
#          [ 80,  86,  84]]],
#
#
#        ...,
#
#
#        [[[ 35, 178, 235],
#          [ 40, 176, 239],
#          [ 42, 176, 241],
#          ...,
#          [ 99, 177, 219],
#          [ 79, 147, 197],
#          [ 89, 148, 189]],
#
#         [[ 57, 182, 234],
#          [ 44, 184, 250],
#          [ 50, 183, 240],
#          ...,
#          [156, 182, 200],
#          [141, 177, 206],
#          [116, 149, 175]],
#
#         [[ 98, 197, 237],
#          [ 64, 189, 252],
#          [ 69, 192, 245],
#          ...,
#          [188, 195, 206],
#          [119, 135, 147],
#          [ 61,  79,  90]],
#
#         ...,
#
#         [[ 73,  79,  77],
#          [ 53,  63,  68],
#          [ 54,  68,  80],
#          ...,
#          [ 17,  40,  64],
#          [ 21,  36,  51],
#          [ 33,  48,  49]],
#
#         [[ 61,  68,  75],
#          [ 55,  70,  86],
#          [ 57,  79, 103],
#          ...,
#          [ 24,  48,  72],
#          [ 17,  35,  53],
#          [  7,  23,  32]],
#
#         [[ 44,  56,  73],
#          [ 46,  66,  88],
#          [ 49,  77, 105],
#          ...,
#          [ 27,  52,  77],
#          [ 21,  43,  66],
#          [ 12,  31,  50]]],
#
#
#        [[[189, 211, 240],
#          [186, 208, 236],
#          [185, 207, 235],
#          ...,
#          [175, 195, 224],
#          [172, 194, 222],
#          [169, 194, 220]],
#
#         [[194, 210, 239],
#          [191, 207, 236],
#          [190, 206, 235],
#          ...,
#          [173, 192, 220],
#          [171, 191, 218],
#          [167, 190, 216]],
#
#         [[208, 219, 244],
#          [205, 216, 240],
#          [204, 215, 239],
#          ...,
#          [175, 191, 217],
#          [172, 190, 216],
#          [169, 191, 215]],
#
#         ...,
#
#         [[207, 199, 181],
#          [203, 195, 175],
#          [203, 196, 173],
#          ...,
#          [135, 132, 127],
#          [162, 158, 150],
#          [168, 163, 151]],
#
#         [[198, 190, 170],
#          [189, 181, 159],
#          [180, 172, 147],
#          ...,
#          [178, 171, 160],
#          [175, 169, 156],
#          [175, 169, 154]],
#
#         [[198, 189, 173],
#          [189, 181, 162],
#          [178, 170, 149],
#          ...,
#          [195, 184, 169],
#          [196, 189, 171],
#          [195, 190, 171]]],
#
#
#        [[[229, 229, 239],
#          [236, 237, 247],
#          [234, 236, 247],
#          ...,
#          [217, 219, 233],
#          [221, 223, 234],
#          [222, 223, 233]],
#
#         [[222, 221, 229],
#          [239, 239, 249],
#          [233, 234, 246],
#          ...,
#          [223, 223, 236],
#          [227, 228, 238],
#          [210, 211, 220]],
#
#         [[213, 206, 211],
#          [234, 232, 239],
#          [231, 233, 244],
#          ...,
#          [220, 220, 232],
#          [220, 219, 232],
#          [202, 203, 215]],
#
#         ...,
#
#         [[150, 143, 135],
#          [140, 135, 127],
#          [132, 127, 120],
#          ...,
#          [224, 222, 218],
#          [230, 228, 225],
#          [241, 241, 238]],
#
#         [[137, 132, 126],
#          [130, 127, 120],
#          [125, 121, 115],
#          ...,
#          [181, 180, 178],
#          [202, 201, 198],
#          [212, 211, 207]],
#
#         [[122, 119, 114],
#          [118, 116, 110],
#          [120, 116, 111],
#          ...,
#          [179, 177, 173],
#          [164, 164, 162],
#          [163, 163, 161]]]], dtype=uint8)

# %% [markdown]
# Os conjuntos previsores são arrays de arrays. Onde cada array interno contém valores de pixel que formam uma imagem.

# %%
y_train
# Out:
# array([[6],
#        [9],
#        [9],
#        ...,
#        [9],
#        [1],
#        [1]], dtype=uint8)

# %% [markdown]
# Os conjuntos de classe possuem arrays de inteiros de 0 a 9, cada um representando uma classe.

# %%
X_train.shape
# Out:
# (50000, 32, 32, 3)

# %% [markdown]
# Os conjuntos previsores já estão com as dimensões exigidas pelo Tensorflow, contendo a dimensão de canais de cor, que no caso são 3, dado que as imagens são coloridas.

# %%
# casting dos conjuntos previsores para futura normalização:
X_train = X_train.astype('float32')
X_test = X_test.astype('float32')

# normalização para reduzir os custos dos cálculos da rede neural:
X_train /= 255
X_test /= 255

# transformação dos conjuntos de classe para codificação One Hot, já que o classificador será uma rede neural:
y_train = utils.to_categorical(y_train)
y_test = utils.to_categorical(y_test)

# %% [markdown]
# # Construção da Rede Neural

# %%
X_train.shape
# Out:
# (50000, 32, 32, 3)

# %%
classifier = Sequential()
classifier.add(InputLayer(shape = (32, 32, 3)))
classifier.add(Conv2D(filters = 32, kernel_size = (3, 3), activation = 'relu'))
classifier.add(BatchNormalization())
classifier.add(MaxPooling2D(pool_size = (2, 2)))
classifier.add(Flatten())
classifier.add(Dense(units = 128, activation = 'relu'))
classifier.add(Dense(units = 10, activation = 'softmax'))

# %%
classifier.compile(optimizer = 'adam', loss = 'categorical_crossentropy', metrics = ['accuracy'])

# %%
classifier.fit(X_train, y_train, batch_size = 128, epochs = 5, validation_data = (X_test, y_test))
# Out:
# Epoch 1/5
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 34s 81ms/step - accuracy: 0.4566 - loss: 1.5823 - val_accuracy: 0.5145 - val_loss: 1.5360
# Epoch 2/5
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 31s 80ms/step - accuracy: 0.6867 - loss: 0.8977 - val_accuracy: 0.6118 - val_loss: 1.1239
# Epoch 3/5
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 42s 82ms/step - accuracy: 0.7743 - loss: 0.6550 - val_accuracy: 0.6107 - val_loss: 1.2431
# Epoch 4/5
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 31s 81ms/step - accuracy: 0.8498 - loss: 0.4481 - val_accuracy: 0.6293 - val_loss: 1.2284
# Epoch 5/5
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 32s 81ms/step - accuracy: 0.9038 - loss: 0.2915 - val_accuracy: 0.6122 - val_loss: 1.6589

# %% [markdown]
# # Testando uma estrutura mais complexa para a rede neural

# %%
k.clear_session()
classifier2 = Sequential()
classifier2.add(InputLayer(shape = (32, 32, 3)))

# 1° bloco:
classifier2.add(Conv2D(filters = 32, kernel_size = (3, 3), activation = 'relu'))
classifier2.add(BatchNormalization())
classifier2.add(MaxPooling2D(pool_size = (2, 2)))

# 2° bloco:
classifier2.add(Conv2D(filters = 32, kernel_size = (3, 3), activation = 'relu'))
classifier2.add(BatchNormalization())
classifier2.add(MaxPooling2D(pool_size = (2, 2)))

classifier2.add(Flatten())

# Rede Neural Densa:
classifier2.add(Dense(units = 128, activation = 'relu'))
classifier2.add(Dropout(0.2))
classifier2.add(Dense(units = 128, activation = 'relu'))
classifier2.add(Dropout(0.2))
classifier2.add(Dense(units = 10, activation = 'softmax'))

# %%
classifier2.compile(optimizer = 'adam', loss = 'categorical_crossentropy', metrics = ['accuracy'])

# %%
classifier2.fit(X_train, y_train, batch_size = 128, epochs = 5,
               validation_data = (X_test, y_test))
# Out:
# Epoch 1/5
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 43s 103ms/step - accuracy: 0.3626 - loss: 1.7881 - val_accuracy: 0.3769 - val_loss: 1.8092
# Epoch 2/5
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 41s 103ms/step - accuracy: 0.5678 - loss: 1.2193 - val_accuracy: 0.6187 - val_loss: 1.0907
# Epoch 3/5
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 41s 104ms/step - accuracy: 0.6424 - loss: 1.0212 - val_accuracy: 0.6498 - val_loss: 0.9937
# Epoch 4/5
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 40s 102ms/step - accuracy: 0.6807 - loss: 0.9107 - val_accuracy: 0.6685 - val_loss: 0.9429
# Epoch 5/5
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 41s 104ms/step - accuracy: 0.7061 - loss: 0.8238 - val_accuracy: 0.6793 - val_loss: 0.9320

# %% [markdown]
# A precisão aumentou, mas não muito.
