# %% [markdown]
# # Standard Deviation and Variance

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

incomes = np.random.normal(100.0, 50.0, 10000)

plt.hist(incomes, 50)
plt.show()

# %%
incomes.std()
# Out:
# 49.77867897796801

# %%
incomes.var()
# Out:
# 2477.9168807915944

# %% [markdown]
# ## Activity

# %% [markdown]
# Experiment with different parameters on the normal function, and see what effect it has on the shape of the distribution. How does that new shape relate to the standard deviation and variance?

# %%
incomes = np.random.normal(70.0, 80.0, 10000)
plt.hist(incomes, 50)
plt.show()

# %%
idades = np.random.randint(1, 100, 800)
plt.hist(idades, 50)
plt.show()

# %%
idades.mean()
# Out:
# 50.195

# %%
idades.std()
# Out:
# 28.576817090081956
